# %%
print("hello world!")
# Out:
# hello world!

# %%
for i in range(1,11):
    if i%2==0:
        print(i,"is even")
    else:
        print(i,"is odd")
print("all done!")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
# all done!

# %%
import pandas as pd

# creating a dataFrame
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({
    'Mamun':['I like Football', 'I like coding'], 
    'Shahrukh':['He likes animes','He likes tv series'], 
    'Tutul':['He likes Programming','He loves portugal football']})
# Out:
#              Mamun            Shahrukh                       Tutul
# 0  I like Football     He likes animes        He likes Programming
# 1    I like coding  He likes tv series  He loves portugal football

# %%
import pandas as pd
df = pd.read_csv('june.csv')
df
# Out:
#             Date\Names       Shuvo  Tutul  Shahrukh  Manik  Mamun  \
# 0             6/1/2021    0.000000    0.0       0.0    0.0    0.0
# 1             6/2/2021    2.000000    NaN       2.5    NaN    2.5
# 2             6/3/2021    1.500000    NaN       2.0    1.0    2.0
# 3             6/4/2021    2.000000    2.0       2.0    2.0    2.0
# 4             6/5/2021    2.500000    2.5       2.5    1.5    2.5
# 5             6/6/2021    2.500000    2.5       1.5    1.5    2.5
# 6             6/7/2021    1.500000    2.5       2.5    1.5    2.5
# 7             6/8/2021    2.500000    2.5       1.5    1.5    1.5
# 8             6/9/2021    1.500000    2.5       2.5    1.5    2.5
# 9            6/10/2021    1.500000    2.5       2.5    1.5    2.5
# 10           6/11/2021    2.500000    2.5       2.5    2.5    2.5
# 11           6/12/2021    2.500000    2.5       2.5    1.5    2.5
# 12           6/13/2021    2.500000    2.5       2.5    1.5    2.5
# ...

# %%
import pandas as pd
df = pd.read_csv('june.csv')
degree_cnt = df['Shahrukh'].value_counts()
degree_cnt
# Out:
# 2.5     22
# 1.5      4
# 2.0      2
# 0.0      1
# 0.5      1
# 1.0      1
# 66.5     1
# Name: Shahrukh, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('june.csv')
degree_cnt = df['Shahrukh'].value_counts()
degree_cnt.plot(kind='bar')
# Out:
# <AxesSubplot:>
