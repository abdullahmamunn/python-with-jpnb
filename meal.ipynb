# %%
import pandas as pd
df = pd.read_csv('june.csv')
df
# Out:
#             Date\Names       Shuvo  Tutul  Shahrukh  Manik  Mamun  \
# 0             6/1/2021    0.000000    0.0       0.0    0.0    0.0
# 1             6/2/2021    2.000000    NaN       2.5    NaN    2.5
# 2             6/3/2021    1.500000    NaN       2.0    1.0    2.0
# 3             6/4/2021    2.000000    2.0       2.0    2.0    2.0
# 4             6/5/2021    2.500000    2.5       2.5    1.5    2.5
# 5             6/6/2021    2.500000    2.5       1.5    1.5    2.5
# 6             6/7/2021    1.500000    2.5       2.5    1.5    2.5
# 7             6/8/2021    2.500000    2.5       1.5    1.5    1.5
# 8             6/9/2021    1.500000    2.5       2.5    1.5    2.5
# 9            6/10/2021    1.500000    2.5       2.5    1.5    2.5
# 10           6/11/2021    2.500000    2.5       2.5    2.5    2.5
# 11           6/12/2021    2.500000    2.5       2.5    1.5    2.5
# 12           6/13/2021    2.500000    2.5       2.5    1.5    2.5
# ...

# %%
df.describe()
# Out:
#             Shuvo      Tutul   Shahrukh      Manik      Mamun  Per Day Meal
# count   34.000000  30.000000  32.000000  31.000000  33.000000     32.000000
# mean    14.246990   4.633333   4.156250   3.258065   5.666667     20.093750
# std     55.730548  12.260065  11.394989   8.784334  13.893944     55.241032
# min      0.000000   0.000000   0.000000   0.000000   0.000000      0.000000
# 25%      1.500000   2.500000   2.000000   1.500000   2.500000      9.875000
# 50%      2.500000   2.500000   2.500000   1.500000   2.500000     11.500000
# 75%      2.500000   2.500000   2.500000   2.250000   2.500000     11.500000
# max    322.500000  69.500000  66.500000  50.500000  71.000000    322.500000
